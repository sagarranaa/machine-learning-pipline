# %% [markdown]
# #### Univariate ,Bivariate and Mutivariate Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')
df.head(70)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# ..  ..            ...           ...            ...           ...
# 65  66            6.7           3.1            4.4           1.4
# 66  67            5.6           3.0            4.5           1.5
# 67  68            5.8           2.7            4.1           1.0
# 68  69            6.2           2.2            4.5           1.5
# 69  70            5.6           2.5            3.9           1.1
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 65  Iris-versicolor
# 66  Iris-versicolor
# 67  Iris-versicolor
# 68  Iris-versicolor
# 69  Iris-versicolor
#
# [70 rows x 6 columns]

# %%
df.shape
# Out:
# (150, 6)

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ### univariate Analysis

# %%
df_setosa=df.loc[df['Species']=='Iris-setosa']

# %%
df_virginica=df.loc[df['Species']=='Iris-virginica']
df_versicolor=df.loc[df['Species']=='Iris-versicolor']

# %%
plt.plot(df_setosa['SepalLengthCm'],np.zeros_like(df_setosa['SepalLengthCm']),'o')
plt.plot(df_virginica['SepalLengthCm'],np.zeros_like(df_virginica['SepalLengthCm']),'o')
plt.plot(df_versicolor['SepalLengthCm'],np.zeros_like(df_versicolor['SepalLengthCm']),'o')
plt.xlabel('sepallength')
plt.show()

# %%
### Bivariate Analysis
sns.FacetGrid(df,hue='Species',size=5).map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend();
plt.show()

# %%
### Bivariate Analysis
sns.FacetGrid(df,hue='Species',size=5).map(plt.scatter,'PetalLengthCm','SepalWidthCm').add_legend();
plt.show()

# %%
### Bivariate Analysis
sns.FacetGrid(df,hue='Species',size=5).map(plt.scatter,'PetalLengthCm','PetalLengthCm').add_legend();
plt.show()

# %%
### Multivariate Analysis
sns.pairplot(df,hue='Species',size=3)
plt.show()
# Out:
# C:\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
